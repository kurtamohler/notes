# %% [markdown]
# ## Compiling `TensorDictParams`
#
# Vincent asked me to look into fixing the behavior of compiled `TensorDictParams`. He gave a few examples here: <https://github.com/pytorch/tensordict/pull/1100#issuecomment-2491805272>

# %% [markdown]
# ### This case works

# %%
from tensordict import from_module, TensorDictParams
import torch.nn

module = torch.nn.Module()
module.params = torch.nn.Parameter(torch.randn(3))
params2 = from_module(module).data.clone()
params2 *= 0
params2 = TensorDictParams(params2)

@torch.compile(fullgraph=True)
def func(z, params2):
    with params2.to_module(module):
        out = z + module.params
    return out

print(func(torch.zeros(()), params2))
# Out:
# tensor([0., 0., 0.], grad_fn=<CompiledFunctionBackward>)

# %% [markdown]
# ### This case does not work

# %%
from tensordict import from_module, TensorDictParams
import torch.nn

module = torch.nn.Module()
module.params = torch.nn.Parameter(torch.randn(3))
params2 = from_module(module).data.clone()
params2 *= 0
params2 = TensorDictParams(params2)
# Isolate the inner tensordict
params2 = params2._param_td

@torch.compile(fullgraph=True)
def func(z, params2):
    with params2.to_module(module):
        out = z + module.params
    return out

print(func(torch.zeros(()), params2))
# Out:
# ---------------------------------------------------------------------------
# Unsupported                               Traceback (most recent call last)
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/ctx_manager.py:170, in GenericContextWrappingVariable.exit(self, tx, *args)
#     169 try:
# --> 170     x = variables.UserMethodVariable(
#     171         self.cm_obj.__exit__.__func__,
#     172         self,
#     173         source=source,
#     174     ).call_function(
#     175         tx,
#     176         [
#     177             variables.ConstantVariable.create(None),
#     178             variables.ConstantVariable.create(None),
#     179             variables.ConstantVariable.create(None),
#     180         ],
#     181         {},
#     182     )
#     183 except Unsupported as e:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:410, in UserMethodVariable.call_function(self, tx, args, kwargs)
#     409     return invoke_and_store_as_constant(tx, fn, self.get_name(), args, kwargs)
# --> 410 return super().call_function(tx, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:349, in UserFunctionVariable.call_function(self, tx, args, kwargs)
#     348             return super().call_function(tx, args, kwargs)
# --> 349 return super().call_function(tx, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:125, in BaseUserFunctionVariable.call_function(self, tx, args, kwargs)
#     119 def call_function(
#     120     self,
#     121     tx: "InstructionTranslator",
#     122     args: "List[VariableTracker]",
#     123     kwargs: "Dict[str, VariableTracker]",
#     124 ) -> "VariableTracker":
# --> 125     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:973, in InstructionTranslatorBase.inline_user_function_return(self, fn, args, kwargs)
#     970 """
#     971 A call to some user defined function by inlining it.
#     972 """
# --> 973 return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:3127, in InliningInstructionTranslator.inline_call(cls, parent, func, args, kwargs)
#    3126 with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
# -> 3127     return cls.inline_call_(parent, func, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:3255, in InliningInstructionTranslator.inline_call_(parent, func, args, kwargs)
#    3254     with strict_ctx:
# -> 3255         tracer.run()
#    3256 except exc.ObservedException as e:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1120, in InstructionTranslatorBase.run(self)
#    1119 self.output.push_tx(self)
# -> 1120 while self.step():
#    1121     pass
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1032, in InstructionTranslatorBase.step(self)
#    1031 try:
# -> 1032     self.dispatch_table[inst.opcode](self, inst)
#    1033     return not self.output.should_exit
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:640, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     639 try:
# --> 640     return inner_fn(self, inst)
#     641 except Unsupported as excp:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1738, in InstructionTranslatorBase.CALL_FUNCTION(self, inst)
#    1737 fn = self.pop()
# -> 1738 self.call_function(fn, args, {})
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:967, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#     966     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 967 self.push(fn.call_function(self, args, kwargs))
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:349, in UserFunctionVariable.call_function(self, tx, args, kwargs)
#     348             return super().call_function(tx, args, kwargs)
# --> 349 return super().call_function(tx, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:125, in BaseUserFunctionVariable.call_function(self, tx, args, kwargs)
#     119 def call_function(
#     120     self,
#     121     tx: "InstructionTranslator",
#     122     args: "List[VariableTracker]",
#     123     kwargs: "Dict[str, VariableTracker]",
#     124 ) -> "VariableTracker":
# --> 125     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:973, in InstructionTranslatorBase.inline_user_function_return(self, fn, args, kwargs)
#     970 """
#     971 A call to some user defined function by inlining it.
#     972 """
# --> 973 return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:3127, in InliningInstructionTranslator.inline_call(cls, parent, func, args, kwargs)
#    3126 with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
# -> 3127     return cls.inline_call_(parent, func, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:3255, in InliningInstructionTranslator.inline_call_(parent, func, args, kwargs)
#    3254     with strict_ctx:
# -> 3255         tracer.run()
#    3256 except exc.ObservedException as e:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1120, in InstructionTranslatorBase.run(self)
#    1119 self.output.push_tx(self)
# -> 1120 while self.step():
#    1121     pass
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1032, in InstructionTranslatorBase.step(self)
#    1031 try:
# -> 1032     self.dispatch_table[inst.opcode](self, inst)
#    1033     return not self.output.should_exit
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:640, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     639 try:
# --> 640     return inner_fn(self, inst)
#     641 except Unsupported as excp:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1816, in InstructionTranslatorBase.CALL_FUNCTION_EX(self, inst)
#    1815 kwargsvars = kwargsvars.keys_as_python_constant()
# -> 1816 self.call_function(fn, argsvars.items, kwargsvars)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:967, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#     966     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 967 self.push(fn.call_function(self, args, kwargs))
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:410, in UserMethodVariable.call_function(self, tx, args, kwargs)
#     409     return invoke_and_store_as_constant(tx, fn, self.get_name(), args, kwargs)
# --> 410 return super().call_function(tx, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:349, in UserFunctionVariable.call_function(self, tx, args, kwargs)
#     348             return super().call_function(tx, args, kwargs)
# --> 349 return super().call_function(tx, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:125, in BaseUserFunctionVariable.call_function(self, tx, args, kwargs)
#     119 def call_function(
#     120     self,
#     121     tx: "InstructionTranslator",
#     122     args: "List[VariableTracker]",
#     123     kwargs: "Dict[str, VariableTracker]",
#     124 ) -> "VariableTracker":
# --> 125     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:973, in InstructionTranslatorBase.inline_user_function_return(self, fn, args, kwargs)
#     970 """
#     971 A call to some user defined function by inlining it.
#     972 """
# --> 973 return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:3127, in InliningInstructionTranslator.inline_call(cls, parent, func, args, kwargs)
#    3126 with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
# -> 3127     return cls.inline_call_(parent, func, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:3255, in InliningInstructionTranslator.inline_call_(parent, func, args, kwargs)
#    3254     with strict_ctx:
# -> 3255         tracer.run()
#    3256 except exc.ObservedException as e:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1120, in InstructionTranslatorBase.run(self)
#    1119 self.output.push_tx(self)
# -> 1120 while self.step():
#    1121     pass
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1032, in InstructionTranslatorBase.step(self)
#    1031 try:
# -> 1032     self.dispatch_table[inst.opcode](self, inst)
#    1033     return not self.output.should_exit
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1896, in InstructionTranslatorBase.STORE_ATTR(self, inst)
#    1895 try:
# -> 1896     BuiltinVariable(setattr).call_function(
#    1897         self, [obj, ConstantVariable.create(inst.argval), val], {}  # type: ignore[arg-type]
#    1898     )
#    1899     return
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/builtin.py:1004, in BuiltinVariable.call_function(self, tx, args, kwargs)
#    1001     self.call_function_handler_cache[key] = handler = self._make_handler(
#    1002         self.fn, [type(x) for x in args], bool(kwargs)
#    1003     )
# -> 1004 return handler(tx, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/builtin.py:843, in BuiltinVariable._make_handler.<locals>.builtin_dispatch(tx, args, kwargs)
#     842 def builtin_dispatch(tx: "InstructionTranslator", args, kwargs):
# --> 843     rv = handler(tx, args, kwargs)
#     844     if rv:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/builtin.py:772, in BuiltinVariable._make_handler.<locals>.call_self_handler(tx, args, kwargs)
#     771 try:
# --> 772     result = self_handler(tx, *args, **kwargs)
#     773     if result is not None:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/builtin.py:1756, in BuiltinVariable.call_setattr(self, tx, obj, name_var, val)
#    1748 if isinstance(
#    1749     obj,
#    1750     (
#    (...)
#    1754     ),
#    1755 ):
# -> 1756     return obj.call_method(tx, "__setattr__", [name_var, val], {})
#    1757 elif (
#    1758     tx.output.side_effects.is_attribute_mutation(obj)
#    1759     and name_var.is_python_constant()
#    1760 ):
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/user_defined.py:744, in UserDefinedObjectVariable.call_method(self, tx, name, args, kwargs)
#     743 if is_standard_setattr(method) or isinstance(self.value, threading.local):
# --> 744     return self.method_setattr_standard(tx, *args, **kwargs)
#     746 # [NOTE] OrderedDict, dict subtypes must always have source
#     747 # We cannot instantiate such subtypes in-graph due to builtin __new__
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/user_defined.py:833, in UserDefinedObjectVariable.method_setattr_standard(self, tx, name, value)
#     832 if not tx.output.side_effects.is_attribute_mutation(self):
# --> 833     unimplemented(f"setattr({self}, {name}, ...)")
#     835 tx.output.side_effects.store_attr(self, name, value)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/exc.py:313, in unimplemented(msg, from_exc, case_name)
#     312     raise Unsupported(msg, case_name=case_name) from from_exc
# --> 313 raise Unsupported(msg, case_name=case_name)
#
# Unsupported: setattr(MutableMappingVariable(TensorDict), _last_op, ...)
#
# The above exception was the direct cause of the following exception:
#
# Unsupported                               Traceback (most recent call last)
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:640, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     639 try:
# --> 640     return inner_fn(self, inst)
#     641 except Unsupported as excp:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1738, in InstructionTranslatorBase.CALL_FUNCTION(self, inst)
#    1737 fn = self.pop()
# -> 1738 self.call_function(fn, args, {})
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:967, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#     966     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 967 self.push(fn.call_function(self, args, kwargs))
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/ctx_manager.py:1223, in WithExitFunctionVariable.call_function(self, tx, args, kwargs)
#    1222 assert not kwargs
# -> 1223 return self.ctx.exit(tx, *args)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/ctx_manager.py:184, in GenericContextWrappingVariable.exit(self, tx, *args)
#     183 except Unsupported as e:
# --> 184     unimplemented(
#     185         f"Unsupported context manager {self.cm_obj}'s __exit__ function",
#     186         from_exc=e,
#     187     )
#     189 tx.generic_context_manager_depth -= 1
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/exc.py:312, in unimplemented(msg, from_exc, case_name)
#     311 if from_exc is not _NOTHING:
# --> 312     raise Unsupported(msg, case_name=case_name) from from_exc
#     313 raise Unsupported(msg, case_name=case_name)
#
# Unsupported: Unsupported context manager TensorDict(
# ...)'s __exit__ function
#
# During handling of the above exception, another exception occurred:
#
# Unsupported                               Traceback (most recent call last)
# Cell In[2], line 18
#      15         out = z + module.params
#      16     return out
# ---> 18 print(func(torch.zeros(()), params2))
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/eval_frame.py:556, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     551 saved_dynamic_layer_stack_depth = (
#     552     torch._C._functorch.get_dynamic_layer_stack_depth()
#     553 )
#     555 try:
# --> 556     return fn(*args, **kwargs)
#     557 finally:
#     558     # Restore the dynamic layer stack depth if necessary.
#     559     torch._C._functorch.pop_dynamic_layer_stack_and_undo_to_depth(
#     560         saved_dynamic_layer_stack_depth
#     561     )
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/convert_frame.py:1395, in CatchErrorsWrapper.__call__(self, frame, cache_entry, frame_state)
#    1389             return hijacked_callback(
#    1390                 frame, cache_entry, self.hooks, frame_state
#    1391             )
#    1393 with compile_lock, _disable_current_modes():
#    1394     # skip=1: skip this frame
# -> 1395     return self._torchdynamo_orig_callable(
#    1396         frame, cache_entry, self.hooks, frame_state, skip=1
#    1397     )
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/convert_frame.py:545, in ConvertFrameAssert.__call__(self, frame, cache_entry, hooks, frame_state, skip)
#     542     dynamo_tls.traced_frame_infos.append(info)
#     544 with compile_context(CompileContext(compile_id)):
# --> 545     return _compile(
#     546         frame.f_code,
#     547         frame.f_globals,
#     548         frame.f_locals,
#     549         frame.f_builtins,
#     550         self._torchdynamo_orig_callable,
#     551         self._one_graph,
#     552         self._export,
#     553         self._export_constraints,
#     554         hooks,
#     555         cache_entry,
#     556         cache_size,
#     557         frame,
#     558         frame_state=frame_state,
#     559         compile_id=compile_id,
#     560         skip=skip + 1,
#     561     )
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/convert_frame.py:977, in _compile(code, globals, locals, builtins, compiler_fn, one_graph, export, export_constraints, hooks, cache_entry, cache_size, frame, frame_state, compile_id, skip)
#     975 guarded_code = None
#     976 try:
# --> 977     guarded_code = compile_inner(code, one_graph, hooks, transform)
#     979     # NB: We only put_code_state in success case.  Success case here
#     980     # does include graph breaks; specifically, if a graph break still
#     981     # resulted in a partially compiled graph, we WILL return here.  An
#    (...)
#     986     # to upload for graph break though, because this can prevent
#     987     # extra graph break compilations.)
#     988     put_code_state()
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/convert_frame.py:706, in _compile.<locals>.compile_inner(code, one_graph, hooks, transform)
#     702     stack.enter_context(
#     703         _WaitCounter("pytorch.wait_counter.dynamo_compile").guard()
#     704     )
#     705     stack.enter_context(CompileTimeInstructionCounter.record())
# --> 706     return _compile_inner(code, one_graph, hooks, transform)
#     708 return None
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_utils_internal.py:95, in compile_time_strobelight_meta.<locals>.compile_time_strobelight_meta_inner.<locals>.wrapper_function(*args, **kwargs)
#      92     kwargs["skip"] = skip + 1
#      94 if not StrobelightCompileTimeProfiler.enabled:
# ---> 95     return function(*args, **kwargs)
#      97 return StrobelightCompileTimeProfiler.profile_compile_time(
#      98     function, phase_name, *args, **kwargs
#      99 )
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/convert_frame.py:741, in _compile.<locals>._compile_inner(code, one_graph, hooks, transform)
#     739 CompileContext.get().attempt = attempt
#     740 try:
# --> 741     out_code = transform_code_object(code, transform)
#     742     break
#     743 except exc.RestartAnalysis as e:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/bytecode_transformation.py:1348, in transform_code_object(code, transformations, safe)
#    1345 instructions = cleaned_instructions(code, safe)
#    1346 propagate_line_nums(instructions)
# -> 1348 transformations(instructions, code_options)
#    1349 return clean_and_assemble_instructions(instructions, keys, code_options)[1]
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/convert_frame.py:229, in preserve_global_state.<locals>._fn(*args, **kwargs)
#     227 exit_stack.enter_context(torch_function_mode_stack_state_mgr)
#     228 try:
# --> 229     return fn(*args, **kwargs)
#     230 finally:
#     231     cleanup.close()
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/convert_frame.py:658, in _compile.<locals>.transform(instructions, code_options)
#     656 try:
#     657     with tracing(tracer.output.tracing_context), tracer.set_current_tx():
# --> 658         tracer.run()
#     659 except exc.UnspecializeRestartAnalysis:
#     660     speculation_log.clear()
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:2912, in InstructionTranslator.run(self)
#    2911 def run(self):
# -> 2912     super().run()
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1120, in InstructionTranslatorBase.run(self)
#    1118 try:
#    1119     self.output.push_tx(self)
# -> 1120     while self.step():
#    1121         pass
#    1122 except BackendCompilerFailed:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1032, in InstructionTranslatorBase.step(self)
#    1029 self.update_block_stack(inst)
#    1031 try:
# -> 1032     self.dispatch_table[inst.opcode](self, inst)
#    1033     return not self.output.should_exit
#    1034 except exc.ObservedException as e:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:646, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     642 if self.generic_context_manager_depth > 0:
#     643     # We don't support graph break under GenericContextWrappingVariable,
#     644     # If there is, we roll back to the checkpoint and fall back.
#     645     excp.remove_from_stats()
# --> 646     unimplemented("Graph break under GenericContextWrappingVariable")
#     648 if isinstance(excp, exc.UncapturedHigherOrderOpError):
#     649     raise
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/exc.py:313, in unimplemented(msg, from_exc, case_name)
#     311 if from_exc is not _NOTHING:
#     312     raise Unsupported(msg, case_name=case_name) from from_exc
# --> 313 raise Unsupported(msg, case_name=case_name)
#
# Unsupported: Graph break under GenericContextWrappingVariable
#
# from user code:
#    File "/tmp/ipykernel_24205/3934583939.py", line 15, in func
#     out = z + module.params
#
# Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
#
#
# You can suppress this exception and fall back to eager by setting:
#     import torch._dynamo
#     torch._dynamo.config.suppress_errors = True

# %% [markdown]
# Notice that the only difference between the two examples aboveis that the second one has the extra line `params2 = params2._param_td` before calling the compiled function. What does this line do?

# %%
from tensordict import from_module, TensorDictParams
import torch.nn

module = torch.nn.Module()
module.params = torch.nn.Parameter(torch.randn(3))
params2 = from_module(module).data.clone()
params2 *= 0
params2 = TensorDictParams(params2)
print(f"before: {type(params2)}")
# Isolate the inner tensordict
params2 = params2._param_td
print(f"after: {type(params2)}")
# Out:
# before: <class 'tensordict.nn.params.TensorDictParams'>
# after: <class 'tensordict._td.TensorDict'>

# %% [markdown]
# As we can see, before the extra line, `params2` is the type `TensorDictParams`. So `TensorDictParams._param_td` gives us the underlying `TensorDict` representation of the `TensorDictParams` object.
#
# As Vincent says, the error is that "dynamo doesn't like that we set attribute to a MutableMapping".
#
# The relevant part from the error message is this:

# %% [markdown]
# ```
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/exc.py:313, in unimplemented(msg, from_exc, case_name)
#     312     raise Unsupported(msg, case_name=case_name) from from_exc
# --> 313 raise Unsupported(msg, case_name=case_name)
#
# Unsupported: setattr(MutableMappingVariable(TensorDict), _last_op, ...)
# ```

# %% [markdown]
# The attribute Vincent is talking about is the `TensorDictParams._param_td`, and `TensorDictParams` is a subclass of `collections.abc.MutableMapping`.

# %%
from tensordict import from_module, TensorDictParams
import torch.nn
from collections.abc import MutableMapping

module = torch.nn.Module()
module.params = torch.nn.Parameter(torch.randn(3))
params2 = from_module(module).data.clone()
params2 *= 0
params2 = TensorDictParams(params2)
print(issubclass(type(params2), MutableMapping))
# Out:
# True

# %% [markdown]
# `MutableMappingVariable` is defined in pytorch under [`torch/_dynamo/variables/user_defined.py`](https://github.com/pytorch/pytorch/blob/f044c1a7c89f1893e2dbef5d3fcc02b7a090484a/torch/_dynamo/variables/user_defined.py#L1412)
#
# On the face of it, it seems like we need to add `MutableMappingVariable.var_setattr`.

# %% [markdown]
# ### Another failing case

# %%
from tensordict import from_module, TensorDictParams, TensorDict
import torch.nn

module = torch.nn.Module()
module.params = TensorDictParams(
    # string="a string!",
    TensorDict(a=0.0)
)
params2 = from_module(module).data.clone()
params2 *= 0
params2 = TensorDictParams(params2)

@torch.compile(fullgraph=True)
def func(z, params2):
    with params2.to_module(module):
        out = z + module.params["a"]
    return out

print(func(torch.zeros(()), params2))
# Out:
# ---------------------------------------------------------------------------
# Unsupported                               Traceback (most recent call last)
# Cell In[9], line 19
#      16         out = z + module.params["a"]
#      17     return out
# ---> 19 print(func(torch.zeros(()), params2))
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/eval_frame.py:556, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     551 saved_dynamic_layer_stack_depth = (
#     552     torch._C._functorch.get_dynamic_layer_stack_depth()
#     553 )
#     555 try:
# --> 556     return fn(*args, **kwargs)
#     557 finally:
#     558     # Restore the dynamic layer stack depth if necessary.
#     559     torch._C._functorch.pop_dynamic_layer_stack_and_undo_to_depth(
#     560         saved_dynamic_layer_stack_depth
#     561     )
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/convert_frame.py:1395, in CatchErrorsWrapper.__call__(self, frame, cache_entry, frame_state)
#    1389             return hijacked_callback(
#    1390                 frame, cache_entry, self.hooks, frame_state
#    1391             )
#    1393 with compile_lock, _disable_current_modes():
#    1394     # skip=1: skip this frame
# -> 1395     return self._torchdynamo_orig_callable(
#    1396         frame, cache_entry, self.hooks, frame_state, skip=1
#    1397     )
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/convert_frame.py:545, in ConvertFrameAssert.__call__(self, frame, cache_entry, hooks, frame_state, skip)
#     542     dynamo_tls.traced_frame_infos.append(info)
#     544 with compile_context(CompileContext(compile_id)):
# --> 545     return _compile(
#     546         frame.f_code,
#     547         frame.f_globals,
#     548         frame.f_locals,
#     549         frame.f_builtins,
#     550         self._torchdynamo_orig_callable,
#     551         self._one_graph,
#     552         self._export,
#     553         self._export_constraints,
#     554         hooks,
#     555         cache_entry,
#     556         cache_size,
#     557         frame,
#     558         frame_state=frame_state,
#     559         compile_id=compile_id,
#     560         skip=skip + 1,
#     561     )
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/convert_frame.py:977, in _compile(code, globals, locals, builtins, compiler_fn, one_graph, export, export_constraints, hooks, cache_entry, cache_size, frame, frame_state, compile_id, skip)
#     975 guarded_code = None
#     976 try:
# --> 977     guarded_code = compile_inner(code, one_graph, hooks, transform)
#     979     # NB: We only put_code_state in success case.  Success case here
#     980     # does include graph breaks; specifically, if a graph break still
#     981     # resulted in a partially compiled graph, we WILL return here.  An
#    (...)
#     986     # to upload for graph break though, because this can prevent
#     987     # extra graph break compilations.)
#     988     put_code_state()
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/convert_frame.py:706, in _compile.<locals>.compile_inner(code, one_graph, hooks, transform)
#     702     stack.enter_context(
#     703         _WaitCounter("pytorch.wait_counter.dynamo_compile").guard()
#     704     )
#     705     stack.enter_context(CompileTimeInstructionCounter.record())
# --> 706     return _compile_inner(code, one_graph, hooks, transform)
#     708 return None
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_utils_internal.py:95, in compile_time_strobelight_meta.<locals>.compile_time_strobelight_meta_inner.<locals>.wrapper_function(*args, **kwargs)
#      92     kwargs["skip"] = skip + 1
#      94 if not StrobelightCompileTimeProfiler.enabled:
# ---> 95     return function(*args, **kwargs)
#      97 return StrobelightCompileTimeProfiler.profile_compile_time(
#      98     function, phase_name, *args, **kwargs
#      99 )
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/convert_frame.py:741, in _compile.<locals>._compile_inner(code, one_graph, hooks, transform)
#     739 CompileContext.get().attempt = attempt
#     740 try:
# --> 741     out_code = transform_code_object(code, transform)
#     742     break
#     743 except exc.RestartAnalysis as e:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/bytecode_transformation.py:1348, in transform_code_object(code, transformations, safe)
#    1345 instructions = cleaned_instructions(code, safe)
#    1346 propagate_line_nums(instructions)
# -> 1348 transformations(instructions, code_options)
#    1349 return clean_and_assemble_instructions(instructions, keys, code_options)[1]
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/convert_frame.py:229, in preserve_global_state.<locals>._fn(*args, **kwargs)
#     227 exit_stack.enter_context(torch_function_mode_stack_state_mgr)
#     228 try:
# --> 229     return fn(*args, **kwargs)
#     230 finally:
#     231     cleanup.close()
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/convert_frame.py:658, in _compile.<locals>.transform(instructions, code_options)
#     656 try:
#     657     with tracing(tracer.output.tracing_context), tracer.set_current_tx():
# --> 658         tracer.run()
#     659 except exc.UnspecializeRestartAnalysis:
#     660     speculation_log.clear()
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:2912, in InstructionTranslator.run(self)
#    2911 def run(self):
# -> 2912     super().run()
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1120, in InstructionTranslatorBase.run(self)
#    1118 try:
#    1119     self.output.push_tx(self)
# -> 1120     while self.step():
#    1121         pass
#    1122 except BackendCompilerFailed:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1032, in InstructionTranslatorBase.step(self)
#    1029 self.update_block_stack(inst)
#    1031 try:
# -> 1032     self.dispatch_table[inst.opcode](self, inst)
#    1033     return not self.output.should_exit
#    1034 except exc.ObservedException as e:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:640, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     638     return handle_graph_break(self, inst, speculation.reason)
#     639 try:
# --> 640     return inner_fn(self, inst)
#     641 except Unsupported as excp:
#     642     if self.generic_context_manager_depth > 0:
#     643         # We don't support graph break under GenericContextWrappingVariable,
#     644         # If there is, we roll back to the checkpoint and fall back.
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1738, in InstructionTranslatorBase.CALL_FUNCTION(self, inst)
#    1736 args = self.popn(inst.argval)
#    1737 fn = self.pop()
# -> 1738 self.call_function(fn, args, {})
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:967, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#     965 if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     966     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 967 self.push(fn.call_function(self, args, kwargs))
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:410, in UserMethodVariable.call_function(self, tx, args, kwargs)
#     408     fn = getattr(self.obj.value, self.fn.__name__)
#     409     return invoke_and_store_as_constant(tx, fn, self.get_name(), args, kwargs)
# --> 410 return super().call_function(tx, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:349, in UserFunctionVariable.call_function(self, tx, args, kwargs)
#     347         with torch._dynamo.side_effects.allow_side_effects_under_checkpoint(tx):
#     348             return super().call_function(tx, args, kwargs)
# --> 349 return super().call_function(tx, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:125, in BaseUserFunctionVariable.call_function(self, tx, args, kwargs)
#     119 def call_function(
#     120     self,
#     121     tx: "InstructionTranslator",
#     122     args: "List[VariableTracker]",
#     123     kwargs: "Dict[str, VariableTracker]",
#     124 ) -> "VariableTracker":
# --> 125     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:973, in InstructionTranslatorBase.inline_user_function_return(self, fn, args, kwargs)
#     969 def inline_user_function_return(self, fn, args, kwargs):
#     970     """
#     971     A call to some user defined function by inlining it.
#     972     """
# --> 973     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:3127, in InliningInstructionTranslator.inline_call(cls, parent, func, args, kwargs)
#    3124 @classmethod
#    3125 def inline_call(cls, parent, func, args, kwargs):
#    3126     with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
# -> 3127         return cls.inline_call_(parent, func, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:3255, in InliningInstructionTranslator.inline_call_(parent, func, args, kwargs)
#    3253 try:
#    3254     with strict_ctx:
# -> 3255         tracer.run()
#    3256 except exc.ObservedException as e:
#    3257     msg = f"Observed exception DURING INLING {code} : {e}"
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1120, in InstructionTranslatorBase.run(self)
#    1118 try:
#    1119     self.output.push_tx(self)
# -> 1120     while self.step():
#    1121         pass
#    1122 except BackendCompilerFailed:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1032, in InstructionTranslatorBase.step(self)
#    1029 self.update_block_stack(inst)
#    1031 try:
# -> 1032     self.dispatch_table[inst.opcode](self, inst)
#    1033     return not self.output.should_exit
#    1034 except exc.ObservedException as e:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:640, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     638     return handle_graph_break(self, inst, speculation.reason)
#     639 try:
# --> 640     return inner_fn(self, inst)
#     641 except Unsupported as excp:
#     642     if self.generic_context_manager_depth > 0:
#     643         # We don't support graph break under GenericContextWrappingVariable,
#     644         # If there is, we roll back to the checkpoint and fall back.
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1816, in InstructionTranslatorBase.CALL_FUNCTION_EX(self, inst)
#    1814 # Map to a dictionary of str -> VariableTracker
#    1815 kwargsvars = kwargsvars.keys_as_python_constant()
# -> 1816 self.call_function(fn, argsvars.items, kwargsvars)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:967, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#     965 if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     966     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 967 self.push(fn.call_function(self, args, kwargs))
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:349, in UserFunctionVariable.call_function(self, tx, args, kwargs)
#     347         with torch._dynamo.side_effects.allow_side_effects_under_checkpoint(tx):
#     348             return super().call_function(tx, args, kwargs)
# --> 349 return super().call_function(tx, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:125, in BaseUserFunctionVariable.call_function(self, tx, args, kwargs)
#     119 def call_function(
#     120     self,
#     121     tx: "InstructionTranslator",
#     122     args: "List[VariableTracker]",
#     123     kwargs: "Dict[str, VariableTracker]",
#     124 ) -> "VariableTracker":
# --> 125     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:973, in InstructionTranslatorBase.inline_user_function_return(self, fn, args, kwargs)
#     969 def inline_user_function_return(self, fn, args, kwargs):
#     970     """
#     971     A call to some user defined function by inlining it.
#     972     """
# --> 973     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:3127, in InliningInstructionTranslator.inline_call(cls, parent, func, args, kwargs)
#    3124 @classmethod
#    3125 def inline_call(cls, parent, func, args, kwargs):
#    3126     with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
# -> 3127         return cls.inline_call_(parent, func, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:3255, in InliningInstructionTranslator.inline_call_(parent, func, args, kwargs)
#    3253 try:
#    3254     with strict_ctx:
# -> 3255         tracer.run()
#    3256 except exc.ObservedException as e:
#    3257     msg = f"Observed exception DURING INLING {code} : {e}"
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1120, in InstructionTranslatorBase.run(self)
#    1118 try:
#    1119     self.output.push_tx(self)
# -> 1120     while self.step():
#    1121         pass
#    1122 except BackendCompilerFailed:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1032, in InstructionTranslatorBase.step(self)
#    1029 self.update_block_stack(inst)
#    1031 try:
# -> 1032     self.dispatch_table[inst.opcode](self, inst)
#    1033     return not self.output.should_exit
#    1034 except exc.ObservedException as e:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:640, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     638     return handle_graph_break(self, inst, speculation.reason)
#     639 try:
# --> 640     return inner_fn(self, inst)
#     641 except Unsupported as excp:
#     642     if self.generic_context_manager_depth > 0:
#     643         # We don't support graph break under GenericContextWrappingVariable,
#     644         # If there is, we roll back to the checkpoint and fall back.
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1828, in InstructionTranslatorBase.CALL_FUNCTION_KW(self, inst)
#    1826 kwargs = dict(zip(argnames, kwargs_list))
#    1827 assert len(kwargs) == len(argnames)
# -> 1828 self.call_function(fn, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:967, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#     965 if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     966     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 967 self.push(fn.call_function(self, args, kwargs))
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:410, in UserMethodVariable.call_function(self, tx, args, kwargs)
#     408     fn = getattr(self.obj.value, self.fn.__name__)
#     409     return invoke_and_store_as_constant(tx, fn, self.get_name(), args, kwargs)
# --> 410 return super().call_function(tx, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:349, in UserFunctionVariable.call_function(self, tx, args, kwargs)
#     347         with torch._dynamo.side_effects.allow_side_effects_under_checkpoint(tx):
#     348             return super().call_function(tx, args, kwargs)
# --> 349 return super().call_function(tx, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:125, in BaseUserFunctionVariable.call_function(self, tx, args, kwargs)
#     119 def call_function(
#     120     self,
#     121     tx: "InstructionTranslator",
#     122     args: "List[VariableTracker]",
#     123     kwargs: "Dict[str, VariableTracker]",
#     124 ) -> "VariableTracker":
# --> 125     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:973, in InstructionTranslatorBase.inline_user_function_return(self, fn, args, kwargs)
#     969 def inline_user_function_return(self, fn, args, kwargs):
#     970     """
#     971     A call to some user defined function by inlining it.
#     972     """
# --> 973     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:3127, in InliningInstructionTranslator.inline_call(cls, parent, func, args, kwargs)
#    3124 @classmethod
#    3125 def inline_call(cls, parent, func, args, kwargs):
#    3126     with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
# -> 3127         return cls.inline_call_(parent, func, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:3255, in InliningInstructionTranslator.inline_call_(parent, func, args, kwargs)
#    3253 try:
#    3254     with strict_ctx:
# -> 3255         tracer.run()
#    3256 except exc.ObservedException as e:
#    3257     msg = f"Observed exception DURING INLING {code} : {e}"
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1120, in InstructionTranslatorBase.run(self)
#    1118 try:
#    1119     self.output.push_tx(self)
# -> 1120     while self.step():
#    1121         pass
#    1122 except BackendCompilerFailed:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1032, in InstructionTranslatorBase.step(self)
#    1029 self.update_block_stack(inst)
#    1031 try:
# -> 1032     self.dispatch_table[inst.opcode](self, inst)
#    1033     return not self.output.should_exit
#    1034 except exc.ObservedException as e:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:640, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     638     return handle_graph_break(self, inst, speculation.reason)
#     639 try:
# --> 640     return inner_fn(self, inst)
#     641 except Unsupported as excp:
#     642     if self.generic_context_manager_depth > 0:
#     643         # We don't support graph break under GenericContextWrappingVariable,
#     644         # If there is, we roll back to the checkpoint and fall back.
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1816, in InstructionTranslatorBase.CALL_FUNCTION_EX(self, inst)
#    1814 # Map to a dictionary of str -> VariableTracker
#    1815 kwargsvars = kwargsvars.keys_as_python_constant()
# -> 1816 self.call_function(fn, argsvars.items, kwargsvars)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:967, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#     965 if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     966     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 967 self.push(fn.call_function(self, args, kwargs))
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:410, in UserMethodVariable.call_function(self, tx, args, kwargs)
#     408     fn = getattr(self.obj.value, self.fn.__name__)
#     409     return invoke_and_store_as_constant(tx, fn, self.get_name(), args, kwargs)
# --> 410 return super().call_function(tx, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:349, in UserFunctionVariable.call_function(self, tx, args, kwargs)
#     347         with torch._dynamo.side_effects.allow_side_effects_under_checkpoint(tx):
#     348             return super().call_function(tx, args, kwargs)
# --> 349 return super().call_function(tx, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:125, in BaseUserFunctionVariable.call_function(self, tx, args, kwargs)
#     119 def call_function(
#     120     self,
#     121     tx: "InstructionTranslator",
#     122     args: "List[VariableTracker]",
#     123     kwargs: "Dict[str, VariableTracker]",
#     124 ) -> "VariableTracker":
# --> 125     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:973, in InstructionTranslatorBase.inline_user_function_return(self, fn, args, kwargs)
#     969 def inline_user_function_return(self, fn, args, kwargs):
#     970     """
#     971     A call to some user defined function by inlining it.
#     972     """
# --> 973     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:3127, in InliningInstructionTranslator.inline_call(cls, parent, func, args, kwargs)
#    3124 @classmethod
#    3125 def inline_call(cls, parent, func, args, kwargs):
#    3126     with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
# -> 3127         return cls.inline_call_(parent, func, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:3255, in InliningInstructionTranslator.inline_call_(parent, func, args, kwargs)
#    3253 try:
#    3254     with strict_ctx:
# -> 3255         tracer.run()
#    3256 except exc.ObservedException as e:
#    3257     msg = f"Observed exception DURING INLING {code} : {e}"
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1120, in InstructionTranslatorBase.run(self)
#    1118 try:
#    1119     self.output.push_tx(self)
# -> 1120     while self.step():
#    1121         pass
#    1122 except BackendCompilerFailed:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1032, in InstructionTranslatorBase.step(self)
#    1029 self.update_block_stack(inst)
#    1031 try:
# -> 1032     self.dispatch_table[inst.opcode](self, inst)
#    1033     return not self.output.should_exit
#    1034 except exc.ObservedException as e:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:640, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     638     return handle_graph_break(self, inst, speculation.reason)
#     639 try:
# --> 640     return inner_fn(self, inst)
#     641 except Unsupported as excp:
#     642     if self.generic_context_manager_depth > 0:
#     643         # We don't support graph break under GenericContextWrappingVariable,
#     644         # If there is, we roll back to the checkpoint and fall back.
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1828, in InstructionTranslatorBase.CALL_FUNCTION_KW(self, inst)
#    1826 kwargs = dict(zip(argnames, kwargs_list))
#    1827 assert len(kwargs) == len(argnames)
# -> 1828 self.call_function(fn, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:967, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#     965 if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     966     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 967 self.push(fn.call_function(self, args, kwargs))
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:410, in UserMethodVariable.call_function(self, tx, args, kwargs)
#     408     fn = getattr(self.obj.value, self.fn.__name__)
#     409     return invoke_and_store_as_constant(tx, fn, self.get_name(), args, kwargs)
# --> 410 return super().call_function(tx, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:349, in UserFunctionVariable.call_function(self, tx, args, kwargs)
#     347         with torch._dynamo.side_effects.allow_side_effects_under_checkpoint(tx):
#     348             return super().call_function(tx, args, kwargs)
# --> 349 return super().call_function(tx, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:125, in BaseUserFunctionVariable.call_function(self, tx, args, kwargs)
#     119 def call_function(
#     120     self,
#     121     tx: "InstructionTranslator",
#     122     args: "List[VariableTracker]",
#     123     kwargs: "Dict[str, VariableTracker]",
#     124 ) -> "VariableTracker":
# --> 125     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:973, in InstructionTranslatorBase.inline_user_function_return(self, fn, args, kwargs)
#     969 def inline_user_function_return(self, fn, args, kwargs):
#     970     """
#     971     A call to some user defined function by inlining it.
#     972     """
# --> 973     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:3127, in InliningInstructionTranslator.inline_call(cls, parent, func, args, kwargs)
#    3124 @classmethod
#    3125 def inline_call(cls, parent, func, args, kwargs):
#    3126     with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
# -> 3127         return cls.inline_call_(parent, func, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:3255, in InliningInstructionTranslator.inline_call_(parent, func, args, kwargs)
#    3253 try:
#    3254     with strict_ctx:
# -> 3255         tracer.run()
#    3256 except exc.ObservedException as e:
#    3257     msg = f"Observed exception DURING INLING {code} : {e}"
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1120, in InstructionTranslatorBase.run(self)
#    1118 try:
#    1119     self.output.push_tx(self)
# -> 1120     while self.step():
#    1121         pass
#    1122 except BackendCompilerFailed:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1032, in InstructionTranslatorBase.step(self)
#    1029 self.update_block_stack(inst)
#    1031 try:
# -> 1032     self.dispatch_table[inst.opcode](self, inst)
#    1033     return not self.output.should_exit
#    1034 except exc.ObservedException as e:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:640, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     638     return handle_graph_break(self, inst, speculation.reason)
#     639 try:
# --> 640     return inner_fn(self, inst)
#     641 except Unsupported as excp:
#     642     if self.generic_context_manager_depth > 0:
#     643         # We don't support graph break under GenericContextWrappingVariable,
#     644         # If there is, we roll back to the checkpoint and fall back.
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1738, in InstructionTranslatorBase.CALL_FUNCTION(self, inst)
#    1736 args = self.popn(inst.argval)
#    1737 fn = self.pop()
# -> 1738 self.call_function(fn, args, {})
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:967, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#     965 if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     966     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 967 self.push(fn.call_function(self, args, kwargs))
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:410, in UserMethodVariable.call_function(self, tx, args, kwargs)
#     408     fn = getattr(self.obj.value, self.fn.__name__)
#     409     return invoke_and_store_as_constant(tx, fn, self.get_name(), args, kwargs)
# --> 410 return super().call_function(tx, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:349, in UserFunctionVariable.call_function(self, tx, args, kwargs)
#     347         with torch._dynamo.side_effects.allow_side_effects_under_checkpoint(tx):
#     348             return super().call_function(tx, args, kwargs)
# --> 349 return super().call_function(tx, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:125, in BaseUserFunctionVariable.call_function(self, tx, args, kwargs)
#     119 def call_function(
#     120     self,
#     121     tx: "InstructionTranslator",
#     122     args: "List[VariableTracker]",
#     123     kwargs: "Dict[str, VariableTracker]",
#     124 ) -> "VariableTracker":
# --> 125     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:973, in InstructionTranslatorBase.inline_user_function_return(self, fn, args, kwargs)
#     969 def inline_user_function_return(self, fn, args, kwargs):
#     970     """
#     971     A call to some user defined function by inlining it.
#     972     """
# --> 973     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:3127, in InliningInstructionTranslator.inline_call(cls, parent, func, args, kwargs)
#    3124 @classmethod
#    3125 def inline_call(cls, parent, func, args, kwargs):
#    3126     with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
# -> 3127         return cls.inline_call_(parent, func, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:3255, in InliningInstructionTranslator.inline_call_(parent, func, args, kwargs)
#    3253 try:
#    3254     with strict_ctx:
# -> 3255         tracer.run()
#    3256 except exc.ObservedException as e:
#    3257     msg = f"Observed exception DURING INLING {code} : {e}"
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1120, in InstructionTranslatorBase.run(self)
#    1118 try:
#    1119     self.output.push_tx(self)
# -> 1120     while self.step():
#    1121         pass
#    1122 except BackendCompilerFailed:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1032, in InstructionTranslatorBase.step(self)
#    1029 self.update_block_stack(inst)
#    1031 try:
# -> 1032     self.dispatch_table[inst.opcode](self, inst)
#    1033     return not self.output.should_exit
#    1034 except exc.ObservedException as e:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:640, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     638     return handle_graph_break(self, inst, speculation.reason)
#     639 try:
# --> 640     return inner_fn(self, inst)
#     641 except Unsupported as excp:
#     642     if self.generic_context_manager_depth > 0:
#     643         # We don't support graph break under GenericContextWrappingVariable,
#     644         # If there is, we roll back to the checkpoint and fall back.
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1828, in InstructionTranslatorBase.CALL_FUNCTION_KW(self, inst)
#    1826 kwargs = dict(zip(argnames, kwargs_list))
#    1827 assert len(kwargs) == len(argnames)
# -> 1828 self.call_function(fn, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:967, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#     965 if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     966     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 967 self.push(fn.call_function(self, args, kwargs))
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:410, in UserMethodVariable.call_function(self, tx, args, kwargs)
#     408     fn = getattr(self.obj.value, self.fn.__name__)
#     409     return invoke_and_store_as_constant(tx, fn, self.get_name(), args, kwargs)
# --> 410 return super().call_function(tx, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:349, in UserFunctionVariable.call_function(self, tx, args, kwargs)
#     347         with torch._dynamo.side_effects.allow_side_effects_under_checkpoint(tx):
#     348             return super().call_function(tx, args, kwargs)
# --> 349 return super().call_function(tx, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:125, in BaseUserFunctionVariable.call_function(self, tx, args, kwargs)
#     119 def call_function(
#     120     self,
#     121     tx: "InstructionTranslator",
#     122     args: "List[VariableTracker]",
#     123     kwargs: "Dict[str, VariableTracker]",
#     124 ) -> "VariableTracker":
# --> 125     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:973, in InstructionTranslatorBase.inline_user_function_return(self, fn, args, kwargs)
#     969 def inline_user_function_return(self, fn, args, kwargs):
#     970     """
#     971     A call to some user defined function by inlining it.
#     972     """
# --> 973     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:3127, in InliningInstructionTranslator.inline_call(cls, parent, func, args, kwargs)
#    3124 @classmethod
#    3125 def inline_call(cls, parent, func, args, kwargs):
#    3126     with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
# -> 3127         return cls.inline_call_(parent, func, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:3255, in InliningInstructionTranslator.inline_call_(parent, func, args, kwargs)
#    3253 try:
#    3254     with strict_ctx:
# -> 3255         tracer.run()
#    3256 except exc.ObservedException as e:
#    3257     msg = f"Observed exception DURING INLING {code} : {e}"
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1120, in InstructionTranslatorBase.run(self)
#    1118 try:
#    1119     self.output.push_tx(self)
# -> 1120     while self.step():
#    1121         pass
#    1122 except BackendCompilerFailed:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1032, in InstructionTranslatorBase.step(self)
#    1029 self.update_block_stack(inst)
#    1031 try:
# -> 1032     self.dispatch_table[inst.opcode](self, inst)
#    1033     return not self.output.should_exit
#    1034 except exc.ObservedException as e:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:640, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     638     return handle_graph_break(self, inst, speculation.reason)
#     639 try:
# --> 640     return inner_fn(self, inst)
#     641 except Unsupported as excp:
#     642     if self.generic_context_manager_depth > 0:
#     643         # We don't support graph break under GenericContextWrappingVariable,
#     644         # If there is, we roll back to the checkpoint and fall back.
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1816, in InstructionTranslatorBase.CALL_FUNCTION_EX(self, inst)
#    1814 # Map to a dictionary of str -> VariableTracker
#    1815 kwargsvars = kwargsvars.keys_as_python_constant()
# -> 1816 self.call_function(fn, argsvars.items, kwargsvars)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:967, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#     965 if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     966     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 967 self.push(fn.call_function(self, args, kwargs))
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:410, in UserMethodVariable.call_function(self, tx, args, kwargs)
#     408     fn = getattr(self.obj.value, self.fn.__name__)
#     409     return invoke_and_store_as_constant(tx, fn, self.get_name(), args, kwargs)
# --> 410 return super().call_function(tx, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:349, in UserFunctionVariable.call_function(self, tx, args, kwargs)
#     347         with torch._dynamo.side_effects.allow_side_effects_under_checkpoint(tx):
#     348             return super().call_function(tx, args, kwargs)
# --> 349 return super().call_function(tx, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:125, in BaseUserFunctionVariable.call_function(self, tx, args, kwargs)
#     119 def call_function(
#     120     self,
#     121     tx: "InstructionTranslator",
#     122     args: "List[VariableTracker]",
#     123     kwargs: "Dict[str, VariableTracker]",
#     124 ) -> "VariableTracker":
# --> 125     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:973, in InstructionTranslatorBase.inline_user_function_return(self, fn, args, kwargs)
#     969 def inline_user_function_return(self, fn, args, kwargs):
#     970     """
#     971     A call to some user defined function by inlining it.
#     972     """
# --> 973     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:3127, in InliningInstructionTranslator.inline_call(cls, parent, func, args, kwargs)
#    3124 @classmethod
#    3125 def inline_call(cls, parent, func, args, kwargs):
#    3126     with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
# -> 3127         return cls.inline_call_(parent, func, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:3255, in InliningInstructionTranslator.inline_call_(parent, func, args, kwargs)
#    3253 try:
#    3254     with strict_ctx:
# -> 3255         tracer.run()
#    3256 except exc.ObservedException as e:
#    3257     msg = f"Observed exception DURING INLING {code} : {e}"
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1120, in InstructionTranslatorBase.run(self)
#    1118 try:
#    1119     self.output.push_tx(self)
# -> 1120     while self.step():
#    1121         pass
#    1122 except BackendCompilerFailed:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1032, in InstructionTranslatorBase.step(self)
#    1029 self.update_block_stack(inst)
#    1031 try:
# -> 1032     self.dispatch_table[inst.opcode](self, inst)
#    1033     return not self.output.should_exit
#    1034 except exc.ObservedException as e:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:640, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     638     return handle_graph_break(self, inst, speculation.reason)
#     639 try:
# --> 640     return inner_fn(self, inst)
#     641 except Unsupported as excp:
#     642     if self.generic_context_manager_depth > 0:
#     643         # We don't support graph break under GenericContextWrappingVariable,
#     644         # If there is, we roll back to the checkpoint and fall back.
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1828, in InstructionTranslatorBase.CALL_FUNCTION_KW(self, inst)
#    1826 kwargs = dict(zip(argnames, kwargs_list))
#    1827 assert len(kwargs) == len(argnames)
# -> 1828 self.call_function(fn, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:967, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#     965 if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     966     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 967 self.push(fn.call_function(self, args, kwargs))
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/user_defined.py:452, in UserDefinedClassVariable.call_function(self, tx, args, kwargs)
#     447         var_cls = GenericContextWrappingVariable
#     449     cm_obj = tx.output.side_effects.track_object_new(
#     450         self.source, self.value, var_cls, {}
#     451     )
# --> 452     cm_obj.call_method(tx, "__init__", args, kwargs)
#     453     return cm_obj
#     454 elif is_namedtuple_cls(self.value):
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/user_defined.py:817, in UserDefinedObjectVariable.call_method(self, tx, name, args, kwargs)
#     815     if method is torch.nn.Module.__init__:
#     816         method = unpatched_nn_module_init
# --> 817     return UserMethodVariable(method, self, source=source).call_function(
#     818         tx, args, kwargs
#     819     )
#     821 if method is list.__len__ and self.source and not (args or kwargs):
#     822     install_guard(self.source.make_guard(GuardBuilder.SEQUENCE_LENGTH))
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:410, in UserMethodVariable.call_function(self, tx, args, kwargs)
#     408     fn = getattr(self.obj.value, self.fn.__name__)
#     409     return invoke_and_store_as_constant(tx, fn, self.get_name(), args, kwargs)
# --> 410 return super().call_function(tx, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:349, in UserFunctionVariable.call_function(self, tx, args, kwargs)
#     347         with torch._dynamo.side_effects.allow_side_effects_under_checkpoint(tx):
#     348             return super().call_function(tx, args, kwargs)
# --> 349 return super().call_function(tx, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:125, in BaseUserFunctionVariable.call_function(self, tx, args, kwargs)
#     119 def call_function(
#     120     self,
#     121     tx: "InstructionTranslator",
#     122     args: "List[VariableTracker]",
#     123     kwargs: "Dict[str, VariableTracker]",
#     124 ) -> "VariableTracker":
# --> 125     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:973, in InstructionTranslatorBase.inline_user_function_return(self, fn, args, kwargs)
#     969 def inline_user_function_return(self, fn, args, kwargs):
#     970     """
#     971     A call to some user defined function by inlining it.
#     972     """
# --> 973     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:3127, in InliningInstructionTranslator.inline_call(cls, parent, func, args, kwargs)
#    3124 @classmethod
#    3125 def inline_call(cls, parent, func, args, kwargs):
#    3126     with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
# -> 3127         return cls.inline_call_(parent, func, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:3255, in InliningInstructionTranslator.inline_call_(parent, func, args, kwargs)
#    3253 try:
#    3254     with strict_ctx:
# -> 3255         tracer.run()
#    3256 except exc.ObservedException as e:
#    3257     msg = f"Observed exception DURING INLING {code} : {e}"
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1120, in InstructionTranslatorBase.run(self)
#    1118 try:
#    1119     self.output.push_tx(self)
# -> 1120     while self.step():
#    1121         pass
#    1122 except BackendCompilerFailed:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1032, in InstructionTranslatorBase.step(self)
#    1029 self.update_block_stack(inst)
#    1031 try:
# -> 1032     self.dispatch_table[inst.opcode](self, inst)
#    1033     return not self.output.should_exit
#    1034 except exc.ObservedException as e:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:640, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     638     return handle_graph_break(self, inst, speculation.reason)
#     639 try:
# --> 640     return inner_fn(self, inst)
#     641 except Unsupported as excp:
#     642     if self.generic_context_manager_depth > 0:
#     643         # We don't support graph break under GenericContextWrappingVariable,
#     644         # If there is, we roll back to the checkpoint and fall back.
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1738, in InstructionTranslatorBase.CALL_FUNCTION(self, inst)
#    1736 args = self.popn(inst.argval)
#    1737 fn = self.pop()
# -> 1738 self.call_function(fn, args, {})
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:967, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#     965 if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     966     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 967 self.push(fn.call_function(self, args, kwargs))
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:410, in UserMethodVariable.call_function(self, tx, args, kwargs)
#     408     fn = getattr(self.obj.value, self.fn.__name__)
#     409     return invoke_and_store_as_constant(tx, fn, self.get_name(), args, kwargs)
# --> 410 return super().call_function(tx, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:349, in UserFunctionVariable.call_function(self, tx, args, kwargs)
#     347         with torch._dynamo.side_effects.allow_side_effects_under_checkpoint(tx):
#     348             return super().call_function(tx, args, kwargs)
# --> 349 return super().call_function(tx, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py:125, in BaseUserFunctionVariable.call_function(self, tx, args, kwargs)
#     119 def call_function(
#     120     self,
#     121     tx: "InstructionTranslator",
#     122     args: "List[VariableTracker]",
#     123     kwargs: "Dict[str, VariableTracker]",
#     124 ) -> "VariableTracker":
# --> 125     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:973, in InstructionTranslatorBase.inline_user_function_return(self, fn, args, kwargs)
#     969 def inline_user_function_return(self, fn, args, kwargs):
#     970     """
#     971     A call to some user defined function by inlining it.
#     972     """
# --> 973     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:3127, in InliningInstructionTranslator.inline_call(cls, parent, func, args, kwargs)
#    3124 @classmethod
#    3125 def inline_call(cls, parent, func, args, kwargs):
#    3126     with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
# -> 3127         return cls.inline_call_(parent, func, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:3255, in InliningInstructionTranslator.inline_call_(parent, func, args, kwargs)
#    3253 try:
#    3254     with strict_ctx:
# -> 3255         tracer.run()
#    3256 except exc.ObservedException as e:
#    3257     msg = f"Observed exception DURING INLING {code} : {e}"
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1120, in InstructionTranslatorBase.run(self)
#    1118 try:
#    1119     self.output.push_tx(self)
# -> 1120     while self.step():
#    1121         pass
#    1122 except BackendCompilerFailed:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1032, in InstructionTranslatorBase.step(self)
#    1029 self.update_block_stack(inst)
#    1031 try:
# -> 1032     self.dispatch_table[inst.opcode](self, inst)
#    1033     return not self.output.should_exit
#    1034 except exc.ObservedException as e:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:640, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     638     return handle_graph_break(self, inst, speculation.reason)
#     639 try:
# --> 640     return inner_fn(self, inst)
#     641 except Unsupported as excp:
#     642     if self.generic_context_manager_depth > 0:
#     643         # We don't support graph break under GenericContextWrappingVariable,
#     644         # If there is, we roll back to the checkpoint and fall back.
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1940, in InstructionTranslatorBase.STORE_SUBSCR(self, inst)
#    1937 @break_graph_if_unsupported(push=0)
#    1938 def STORE_SUBSCR(self, inst):
#    1939     val, obj, key = self.popn(3)
# -> 1940     result = obj.call_method(self, "__setitem__", [key, val], {})
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/misc.py:1080, in GetAttrVariable.call_method(self, tx, name, args, kwargs)
#    1077     else:
#    1078         return variables.ConstantVariable(False)
# -> 1080 return super().call_method(tx, name, args, kwargs)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/base.py:424, in VariableTracker.call_method(self, tx, name, args, kwargs)
#     417 elif (
#     418     name == "__getattr__"
#     419     and len(args) == 1
#     420     and args[0].is_python_constant()
#     421     and not kwargs
#     422 ):
#     423     return self.var_getattr(tx, args[0].as_python_constant())
# --> 424 unimplemented(f"call_method {self} {name} {args} {kwargs}")
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/exc.py:313, in unimplemented(msg, from_exc, case_name)
#     311 if from_exc is not _NOTHING:
#     312     raise Unsupported(msg, case_name=case_name) from from_exc
# --> 313 raise Unsupported(msg, case_name=case_name)
#
# Unsupported: call_method GetAttrVariable(GenericContextWrappingVariable(TensorDictParams), __dict__) __setitem__ [ConstantVariable(str: '_parameters'), ConstDictVariable()] {}
#
# from user code:
#    File "/tmp/ipykernel_24205/1940307110.py", line 15, in func
#     with params2.to_module(module):
#   File "/home/endoplasm/develop/tensordict-0/tensordict/utils.py", line 1238, in new_func
#     out = func(_self, *args, **kwargs)
#   File "/home/endoplasm/develop/tensordict-0/tensordict/base.py", line 1704, in to_module
#     return self._to_module(
#   File "/home/endoplasm/develop/tensordict-0/tensordict/nn/params.py", line 190, in new_func
#     out = getattr(self._param_td, name)(*args, **kwargs)
#   File "/home/endoplasm/develop/tensordict-0/tensordict/_td.py", line 577, in _to_module
#     local_out = value._to_module(
#   File "/home/endoplasm/develop/tensordict-0/tensordict/_td.py", line 482, in _to_module
#     swap = module.copy()
#   File "/home/endoplasm/develop/tensordict-0/tensordict/base.py", line 9685, in copy
#     return self.clone(recurse=False)
#   File "/home/endoplasm/develop/tensordict-0/tensordict/base.py", line 9672, in clone
#     result = self._clone(recurse=recurse, **kwargs)
#   File "/home/endoplasm/develop/tensordict-0/tensordict/nn/params.py", line 623, in _clone
#     return TensorDictParams(self._param_td._clone(False), no_convert="skip")
#   File "/home/endoplasm/develop/tensordict-0/tensordict/nn/params.py", line 340, in __init__
#     self._reset_params()
#   File "/home/endoplasm/develop/tensordict-0/tensordict/nn/params.py", line 384, in _reset_params
#     self.__dict__["_parameters"] = dict(zip(param_keys, params))
#
# Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
#
#
# You can suppress this exception and fall back to eager by setting:
#     import torch._dynamo
#     torch._dynamo.config.suppress_errors = True

# %% [markdown]
# The illuminating part of the error is:

# %% [markdown]
# ```
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/exc.py:313, in unimplemented(msg, from_exc, case_name)
#     311 if from_exc is not _NOTHING:
#     312     raise Unsupported(msg, case_name=case_name) from from_exc
# --> 313 raise Unsupported(msg, case_name=case_name)
#
# Unsupported: call_method GetAttrVariable(GenericContextWrappingVariable(TensorDictParams), __dict__) __setitem__ [ConstantVariable(str: '_parameters'), ConstDictVariable()] {}
# ```

# %% [markdown]
# ### PyTorch issue
#
#
# Vincent posted an pytorch issue: <https://github.com/pytorch/pytorch/issues/141118>
#
# He mentions that `TensorDictParms` inherits from multiple classes (`MutableMapping` and `UnspecializedNNModuleVariable`).
#
# He brings up another case that fails compilation:

# %%
import torch
from tensordict import TensorDictParams, TensorDict

td = TensorDictParams(TensorDict(a=1, b=2, c=True))

@torch.compile(fullgraph=True)
def add1(td):
    return TensorDict(**td)+1

add1(td)
# Out:
# ---------------------------------------------------------------------------
# Unsupported                               Traceback (most recent call last)
# Cell In[10], line 10
#       6 @torch.compile(fullgraph=True)
#       7 def add1(td):
#       8     return TensorDict(**td)+1
# ---> 10 add1(td)
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/eval_frame.py:556, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     551 saved_dynamic_layer_stack_depth = (
#     552     torch._C._functorch.get_dynamic_layer_stack_depth()
#     553 )
#     555 try:
# --> 556     return fn(*args, **kwargs)
#     557 finally:
#     558     # Restore the dynamic layer stack depth if necessary.
#     559     torch._C._functorch.pop_dynamic_layer_stack_and_undo_to_depth(
#     560         saved_dynamic_layer_stack_depth
#     561     )
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/convert_frame.py:1395, in CatchErrorsWrapper.__call__(self, frame, cache_entry, frame_state)
#    1389             return hijacked_callback(
#    1390                 frame, cache_entry, self.hooks, frame_state
#    1391             )
#    1393 with compile_lock, _disable_current_modes():
#    1394     # skip=1: skip this frame
# -> 1395     return self._torchdynamo_orig_callable(
#    1396         frame, cache_entry, self.hooks, frame_state, skip=1
#    1397     )
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/convert_frame.py:545, in ConvertFrameAssert.__call__(self, frame, cache_entry, hooks, frame_state, skip)
#     542     dynamo_tls.traced_frame_infos.append(info)
#     544 with compile_context(CompileContext(compile_id)):
# --> 545     return _compile(
#     546         frame.f_code,
#     547         frame.f_globals,
#     548         frame.f_locals,
#     549         frame.f_builtins,
#     550         self._torchdynamo_orig_callable,
#     551         self._one_graph,
#     552         self._export,
#     553         self._export_constraints,
#     554         hooks,
#     555         cache_entry,
#     556         cache_size,
#     557         frame,
#     558         frame_state=frame_state,
#     559         compile_id=compile_id,
#     560         skip=skip + 1,
#     561     )
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/convert_frame.py:977, in _compile(code, globals, locals, builtins, compiler_fn, one_graph, export, export_constraints, hooks, cache_entry, cache_size, frame, frame_state, compile_id, skip)
#     975 guarded_code = None
#     976 try:
# --> 977     guarded_code = compile_inner(code, one_graph, hooks, transform)
#     979     # NB: We only put_code_state in success case.  Success case here
#     980     # does include graph breaks; specifically, if a graph break still
#     981     # resulted in a partially compiled graph, we WILL return here.  An
#    (...)
#     986     # to upload for graph break though, because this can prevent
#     987     # extra graph break compilations.)
#     988     put_code_state()
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/convert_frame.py:706, in _compile.<locals>.compile_inner(code, one_graph, hooks, transform)
#     702     stack.enter_context(
#     703         _WaitCounter("pytorch.wait_counter.dynamo_compile").guard()
#     704     )
#     705     stack.enter_context(CompileTimeInstructionCounter.record())
# --> 706     return _compile_inner(code, one_graph, hooks, transform)
#     708 return None
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_utils_internal.py:95, in compile_time_strobelight_meta.<locals>.compile_time_strobelight_meta_inner.<locals>.wrapper_function(*args, **kwargs)
#      92     kwargs["skip"] = skip + 1
#      94 if not StrobelightCompileTimeProfiler.enabled:
# ---> 95     return function(*args, **kwargs)
#      97 return StrobelightCompileTimeProfiler.profile_compile_time(
#      98     function, phase_name, *args, **kwargs
#      99 )
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/convert_frame.py:741, in _compile.<locals>._compile_inner(code, one_graph, hooks, transform)
#     739 CompileContext.get().attempt = attempt
#     740 try:
# --> 741     out_code = transform_code_object(code, transform)
#     742     break
#     743 except exc.RestartAnalysis as e:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/bytecode_transformation.py:1348, in transform_code_object(code, transformations, safe)
#    1345 instructions = cleaned_instructions(code, safe)
#    1346 propagate_line_nums(instructions)
# -> 1348 transformations(instructions, code_options)
#    1349 return clean_and_assemble_instructions(instructions, keys, code_options)[1]
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/convert_frame.py:229, in preserve_global_state.<locals>._fn(*args, **kwargs)
#     227 exit_stack.enter_context(torch_function_mode_stack_state_mgr)
#     228 try:
# --> 229     return fn(*args, **kwargs)
#     230 finally:
#     231     cleanup.close()
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/convert_frame.py:658, in _compile.<locals>.transform(instructions, code_options)
#     656 try:
#     657     with tracing(tracer.output.tracing_context), tracer.set_current_tx():
# --> 658         tracer.run()
#     659 except exc.UnspecializeRestartAnalysis:
#     660     speculation_log.clear()
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:2912, in InstructionTranslator.run(self)
#    2911 def run(self):
# -> 2912     super().run()
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1120, in InstructionTranslatorBase.run(self)
#    1118 try:
#    1119     self.output.push_tx(self)
# -> 1120     while self.step():
#    1121         pass
#    1122 except BackendCompilerFailed:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:1032, in InstructionTranslatorBase.step(self)
#    1029 self.update_block_stack(inst)
#    1031 try:
# -> 1032     self.dispatch_table[inst.opcode](self, inst)
#    1033     return not self.output.should_exit
#    1034 except exc.ObservedException as e:
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py:2262, in InstructionTranslatorBase.DICT_MERGE(self, inst)
#    2260 assert isinstance(obj, ConstDictVariable)
#    2261 assert obj.is_mutable()
# -> 2262 obj.call_method(self, "update", [v], {})
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/dicts.py:357, in ConstDictVariable.call_method(self, tx, name, args, kwargs)
#     355         dict_vt = args[0]
#     356     else:
# --> 357         dict_vt = BuiltinVariable.call_custom_dict(tx, dict, args[0])
#     358     self.items.update(dict_vt.items)
#     359 # Wrap strings
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/variables/builtin.py:1422, in BuiltinVariable.call_custom_dict(tx, user_cls, *args, **kwargs)
#    1418     items = {ConstantVariable.create(k): v for k, v in kwargs.items()}
#    1419     return variables.ConstDictVariable(
#    1420         items, user_cls=user_cls, mutation_type=ValueMutationNew()
#    1421     )
# -> 1422 unimplemented(f"{user_cls.__name__}(): {args} {kwargs}")
#
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/exc.py:313, in unimplemented(msg, from_exc, case_name)
#     311 if from_exc is not _NOTHING:
#     312     raise Unsupported(msg, case_name=case_name) from from_exc
# --> 313 raise Unsupported(msg, case_name=case_name)
#
# Unsupported: dict(): (UnspecializedNNModuleVariable(TensorDictParams),) {}
#
# from user code:
#    File "/tmp/ipykernel_24205/2760013897.py", line 8, in add1
#     return TensorDict(**td)+1
#
# Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
#
#
# You can suppress this exception and fall back to eager by setting:
#     import torch._dynamo
#     torch._dynamo.config.suppress_errors = True

# %% [markdown]
# In short, the error is:

# %% [markdown]
# ```
# File ~/miniconda/envs/tensordict-0/lib/python3.9/site-packages/torch/_dynamo/exc.py:313, in unimplemented(msg, from_exc, case_name)
#     311 if from_exc is not _NOTHING:
#     312     raise Unsupported(msg, case_name=case_name) from from_exc
# --> 313 raise Unsupported(msg, case_name=case_name)
#
# Unsupported: dict(): (UnspecializedNNModuleVariable(TensorDictParams),) {}
# ```

# %% [markdown]
# Of course one question is still: How do we fix the error?
#
# But another question is: How does dynamo decide which of the multiple base classes to resolve to?
#
# `MutableMappingUnspecializedNNModuleVariable` is defined under [`torch/_dynamo/variables/nn_module.py`](https://github.com/pytorch/pytorch/blob/f869a0ffe1c42c2c4a95d9d22f49260e7ce5fdb9/torch/_dynamo/variables/nn_module.py#L764)
#
# In the above example, the params got resolved to `UnspecializedNNModuleVariable(TensorDictParams)` rather than a `MutableMappingVariable`.

# %%
def func(**kwargs):
    print(kwargs)
    print(type(kwargs))
func(**td)
# Out:
# {'a': tensor(1), 'b': tensor(2), 'c': tensor(True)}
# <class 'dict'>
